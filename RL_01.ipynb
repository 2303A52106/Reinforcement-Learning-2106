# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52106/Reinforcement-Learning-2106/blob/main/RL_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Greedy Algorithm for Multi-Armed Bandit
# Using the Arithmetic Mean method to estimate Q(a)

# %%
def calculate_q_arithmetic_mean(rewards):
    """Q(a) = (Sum of rewards for action a) / (N(a))"""
    return sum(rewards) / len(rewards)


def main():
    n = int(input("Enter the number of machines: "))

    machine_names = []
    machine_rewards = {}

    for i in range(n):
        name = input(f"Enter name of machine {i + 1}: ").strip()
        rewards_str = input(f"Enter observed rewards for machine {name} (comma separated): ")
        rewards = [float(x.strip()) for x in rewards_str.split(",")]
        machine_names.append(name)
        machine_rewards[name] = rewards

    q_values = {}

    print("\n--- Results ---")
    for name in machine_names:
        rewards = machine_rewards[name]
        q = calculate_q_arithmetic_mean(rewards)
        q_values[name] = q
        print(f"\nMachine {name}")
        print(f"Rewards: {rewards}")
        print(f"Q({name}) = {q:.2f}")

    selected_machine = max(q_values, key=q_values.get)
    print(f"\nGreedy Selected Machine: {selected_machine}")


if __name__ == "__main__":
    main()
# Out:
# Enter the number of machines: 3
# Enter name of machine 1: A
# Enter observed rewards for machine A (comma separated): 3,4,2,5
# Enter name of machine 2: B
# Enter observed rewards for machine B (comma separated): 6,7,5,8
# Enter name of machine 3: C
# Enter observed rewards for machine C (comma separated): 4,3,5,4
#
# --- Results ---
#
# Machine A
# Rewards: [3.0, 4.0, 2.0, 5.0]
# Q(A) = 3.50
#
# Machine B
# Rewards: [6.0, 7.0, 5.0, 8.0]
# Q(B) = 6.50
#
# Machine C
# Rewards: [4.0, 3.0, 5.0, 4.0]
# Q(C) = 4.00
#
# Greedy Selected Machine: B
